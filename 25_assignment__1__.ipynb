# %%
print("hello python")
# Out:
# hello python

# %%
a = int(input("enter a number1 :"))
b = int(input("enter a number2 :"))

num = a + b
print("addition :", num)
# Out:
# enter a number1 : 10
# enter a number2 : 20
# addition : 30

# %%
a = int(input("enter a number1 :"))
b = int(input("enter a number2 :"))

num = a // b
print("division :", num)
# Out:
# enter a number1 : 10
# enter a number2 : 5
# division : 2

# %%
base = int(input("enter a number :"))
hight = int(input("enter a number :"))

area = 1/2 * base * hight

print("area of trangle is :", area)
# Out:
# enter a number : 12
# enter a number : 24
# area of trangle is : 144.0

# %%
a = int(input("enter value a :"))
b = int(input("enter value b :"))

temp = a
a = b
b = temp

print(f" swap variable is a = {a} , b = {b}")
# Out:
# enter value a : 2
# enter value b : 4
#  swap variable is a = 4 , b = 2

# %%
a = int(input("enter value a :"))
b = int(input("enter value b :"))

a, b = b, a


print(f" swap variable is a = {a} , b = {b}")
# Out:
# enter value a : 2
# enter value b : 5
#  swap variable is a = 5 , b = 2

# %%
import random

# %%
random_number = random.randint(1, 100)

print("random number is :", random_number)
# Out:
# random number is : 71
